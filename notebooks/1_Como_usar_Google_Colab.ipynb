# %% [markdown]
# # <font color='green'>Física Computacional - Fundamentos Python</font>
# ## <font color='blue'>1-Trabalhando com o Google Colab</font>
#
#
#
# 1.   python
# 2.   computação
# 3.   aula

# %% [markdown]
# Apresentando o Google Colab:
#
# - Acessando a partir de uma conta
# -https://colab.research.google.com/?utm_source=scs-index
# - Comandos principais (Shift+Enter...)
# - Configurações/Preferências

# %%
#Comentários
print("física")
# Out:
# física

# %%
a = "física"

# %%
a
# Out:
# 'física'

# %%
print(a)
# Out:
# física

# %%
5 + 15
# Out:
# 20

# %%
50 - 100
# Out:
# -50

# %% [markdown]
# # Fim!!
